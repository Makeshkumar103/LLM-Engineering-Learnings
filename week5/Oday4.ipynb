# %% [markdown]
# # RAG Day 4
#
# ## Evaluation!
#
# <table style="margin: 0; text-align: left;">
#     <tr>
#         <td style="width: 150px; height: 150px; vertical-align: middle;">
#             <img src="../assets/business.jpg" width="150" height="150" style="display: block;" />
#         </td>
#         <td>
#             <h2 style="color:#181;">Keep in mind how you would evaluate RAG for your business</h2>
#             <span style="color:#181;">This is such an important part of building an accurate and reliable RAG pipeline. And it's applicable to many aspects of solving business problems with LLMs. People are often focused on RAG architecture and RAG frameworks for their business. But even more important: evaluations!</span>
#         </td>
#     </tr>
# </table>

# %%
from evaluation import test

# %%
tests = test.load_tests()

# %%
len(tests)
# Out:
# 150

# %%
example = tests[3]
print(example.question)
print(example.category)
print(example.reference_answer)
print(example.keywords)
# Out:
# How many employees does Insurellm currently have?
# direct_fact
# Insurellm currently operates with 32 employees as of 2025.
# ['32', 'employees']

# %%
from collections import Counter
count = Counter([t.category for t in tests])
count
# Out:
# Counter({'direct_fact': 70,
#          'temporal': 20,
#          'spanning': 20,
#          'comparative': 10,
#          'numerical': 10,
#          'relationship': 10,
#          'holistic': 10})

# %%
from evaluation.eval import evaluate_retrieval, evaluate_answer

# %%
evaluate_retrieval(example)
# Out:
# RetrievalEval(mrr=0.6666666666666666, ndcg=0.7408808173675422, keywords_found=2, total_keywords=2, keyword_coverage=100.0)

# %%
eval, answer, chunks = evaluate_answer(example)

# %%
eval
# Out:
# AnswerEval(feedback='The answer correctly states that Insurellm has 32 employees, matching the reference. It provides additional context about remote work and office locations, which is not required but does not mislead. This extra information does not affect factual accuracy but slightly lowers relevance as the question only asked for the employee count.', accuracy=5.0, completeness=5.0, relevance=4.0)

# %%
print(eval.feedback)
print(eval.accuracy)
print(eval.completeness)
print(eval.relevance)
# Out:
# The answer correctly states that Insurellm has 32 employees, matching the reference. It provides additional context about remote work and office locations, which is not required but does not mislead. This extra information does not affect factual accuracy but slightly lowers relevance as the question only asked for the employee count.
# 5.0
# 5.0
# 4.0

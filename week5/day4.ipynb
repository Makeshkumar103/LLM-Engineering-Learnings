# %% [markdown]
# # RAG Day 4
#
# ## Evaluation!
#
# <table style="margin: 0; text-align: left;">
#     <tr>
#         <td style="width: 150px; height: 150px; vertical-align: middle;">
#             <img src="../assets/business.jpg" width="150" height="150" style="display: block;" />
#         </td>
#         <td>
#             <h2 style="color:#181;">Keep in mind how you would evaluate RAG for your business</h2>
#             <span style="color:#181;">This is such an important part of building an accurate and reliable RAG pipeline. And it's applicable to many aspects of solving business problems with LLMs. People are often focused on RAG architecture and RAG frameworks for their business. But even more important: evaluations!</span>
#         </td>
#     </tr>
# </table>

# %%
import sys
print("sys : ",sys.executable)
import groq
print(groq.__version__)
import importlib.metadata

print(importlib.metadata.version("groq"))
import groq
print(groq)
print(groq.__file__)
# Out:
# sys :  e:\MK\AI projects\Agentic-core\llm_engineering\.venv\Scripts\python.exe
# 0.33.0
# 0.33.0
# <module 'groq' from 'e:\\MK\\AI projects\\Agentic-core\\llm_engineering\\.venv\\Lib\\site-packages\\groq\\__init__.py'>
# e:\MK\AI projects\Agentic-core\llm_engineering\.venv\Lib\site-packages\groq\__init__.py

# %%
from evaluation import test

# %%
tests = test.load_tests()

# %%
len(tests)
# Out:
# 150

# %%
example = tests[2]
print(example.question)
print(example.category)
print(example.reference_answer)
print(example.keywords)
# Out:
# Who founded Insurellm?
# direct_fact
# Avery Lancaster founded Insurellm in 2015.
# ['Avery', 'Lancaster']

# %%
from collections import Counter
count = Counter([t.category for t in tests])
count
# Out:
# Counter({'direct_fact': 70,
#          'temporal': 20,
#          'spanning': 20,
#          'comparative': 10,
#          'numerical': 10,
#          'relationship': 10,
#          'holistic': 10})

# %%
from evaluation.eval import evaluate_retrieval, evaluate_answer

# %%
evaluate_retrieval(example)
# Out:
# RetrievalEval(mrr=1.0, ndcg=0.9197207891481876, keywords_found=2, total_keywords=2, keyword_coverage=100.0)

# %%
eval, answer, chunks = evaluate_answer(example)
# Out:
# ---------------------------------------------------------------------------
# BadRequestError                           Traceback (most recent call last)
# Cell In[8], line 1
# ----> 1 eval, answer, chunks = evaluate_answer(example)
#
# File e:\MK\AI projects\LLM-Engineering_Learning\llm_engineering\week5\evaluation\eval.py:170, in evaluate_answer(test)
#     139 judge_messages = [
#     140     {
#     141         "role": "system",
#    (...)    161     },
#     162 ]
#     164 # Call LLM judge with structured outputs (async)
#     165 # judge_response = completion(model=MODEL, messages=judge_messages, response_format=AnswerEval)
#     166
#     167 # answer_eval = AnswerEval.model_validate_json(judge_response.choices[0].message.content)
#     168
#     169 # return answer_eval, generated_answer, retrieved_docs
# --> 170 judge_response = groqcall.chat.completions.create(model=GROQ_MODEL, messages=judge_messages, response_format={"type": "json_object"})
#     171 answer_eval = AnswerEval.model_validate_json(judge_response.choices[0].message.content)
#     172 return answer_eval, generated_answer, retrieved_docs
#
# File e:\MK\AI projects\Agentic-core\llm_engineering\.venv\Lib\site-packages\groq\resources\chat\completions.py:464, in Completions.create(self, messages, model, citation_options, compound_custom, disable_tool_validation, documents, exclude_domains, frequency_penalty, function_call, functions, include_domains, include_reasoning, logit_bias, logprobs, max_completion_tokens, max_tokens, metadata, n, parallel_tool_calls, presence_penalty, reasoning_effort, reasoning_format, response_format, search_settings, seed, service_tier, stop, store, stream, temperature, tool_choice, tools, top_logprobs, top_p, user, extra_headers, extra_query, extra_body, timeout)
#     244 def create(
#     245     self,
#     246     *,
#    (...)    303     timeout: float | httpx.Timeout | None | NotGiven = not_given,
#     304 ) -> ChatCompletion | Stream[ChatCompletionChunk]:
#     305     """
#     306     Creates a model response for the given chat conversation.
#     307
#    (...)    462       timeout: Override the client-level default timeout for this request, in seconds
#     463     """
# --> 464     return self._post(
#     465         "/openai/v1/chat/completions",
#     466         body=maybe_transform(
#     467             {
#     468                 "messages": messages,
#     469                 "model": model,
#     470                 "citation_options": citation_options,
#     471                 "compound_custom": compound_custom,
#     472                 "disable_tool_validation": disable_tool_validation,
#     473                 "documents": documents,
#     474                 "exclude_domains": exclude_domains,
#     475                 "frequency_penalty": frequency_penalty,
#     476                 "function_call": function_call,
#     477                 "functions": functions,
#     478                 "include_domains": include_domains,
#     479                 "include_reasoning": include_reasoning,
#     480                 "logit_bias": logit_bias,
#     481                 "logprobs": logprobs,
#     482                 "max_completion_tokens": max_completion_tokens,
#     483                 "max_tokens": max_tokens,
#     484                 "metadata": metadata,
#     485                 "n": n,
#     486                 "parallel_tool_calls": parallel_tool_calls,
#     487                 "presence_penalty": presence_penalty,
#     488                 "reasoning_effort": reasoning_effort,
#     489                 "reasoning_format": reasoning_format,
#     490                 "response_format": response_format,
#     491                 "search_settings": search_settings,
#     492                 "seed": seed,
#     493                 "service_tier": service_tier,
#     494                 "stop": stop,
#     495                 "store": store,
#     496                 "stream": stream,
#     497                 "temperature": temperature,
#     498                 "tool_choice": tool_choice,
#     499                 "tools": tools,
#     500                 "top_logprobs": top_logprobs,
#     501                 "top_p": top_p,
#     502                 "user": user,
#     503             },
#     504             completion_create_params.CompletionCreateParams,
#     505         ),
#     506         options=make_request_options(
#     507             extra_headers=extra_headers, extra_query=extra_query, extra_body=extra_body, timeout=timeout
#     508         ),
#     509         cast_to=ChatCompletion,
#     510         stream=stream or False,
#     511         stream_cls=Stream[ChatCompletionChunk],
#     512     )
#
# File e:\MK\AI projects\Agentic-core\llm_engineering\.venv\Lib\site-packages\groq\_base_client.py:1242, in SyncAPIClient.post(self, path, cast_to, body, options, files, stream, stream_cls)
#    1228 def post(
#    1229     self,
#    1230     path: str,
#    (...)   1237     stream_cls: type[_StreamT] | None = None,
#    1238 ) -> ResponseT | _StreamT:
#    1239     opts = FinalRequestOptions.construct(
#    1240         method="post", url=path, json_data=body, files=to_httpx_files(files), **options
#    1241     )
# -> 1242     return cast(ResponseT, self.request(cast_to, opts, stream=stream, stream_cls=stream_cls))
#
# File e:\MK\AI projects\Agentic-core\llm_engineering\.venv\Lib\site-packages\groq\_base_client.py:1044, in SyncAPIClient.request(self, cast_to, options, stream, stream_cls)
#    1041             err.response.read()
#    1043         log.debug("Re-raising status error")
# -> 1044         raise self._make_status_error_from_response(err.response) from None
#    1046     break
#    1048 assert response is not None, "could not resolve response (should never happen)"
#
# BadRequestError: Error code: 400 - {'error': {'message': "'messages' must contain the word 'json' in some form, to use 'response_format' of type 'json_object'.", 'type': 'invalid_request_error'}}

# %%
eval

# %%
print(eval.feedback)
print(eval.accuracy)
print(eval.completeness)
print(eval.relevance)

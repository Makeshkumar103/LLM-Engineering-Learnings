# %% [markdown]
# # Code Generator
#
# The requirement: use a Frontier model to generate high performance C++ code from Python code

# %% [markdown]
# <table style="margin: 0; text-align: left;">
#     <tr>
#         <td style="width: 150px; height: 150px; vertical-align: middle;">
#             <img src="../assets/resources.jpg" width="150" height="150" style="display: block;" />
#         </td>
#         <td>
#             <h2 style="color:#f71;">Reminder: fetch latest code</h2>
#             <span style="color:#f71;">I'm continually improving these labs, adding more examples and exercises.
#             At the start of each week, it's worth checking you have the latest code.<br/>
#             First do a <a href="https://chatgpt.com/share/6734e705-3270-8012-a074-421661af6ba9">git pull and merge your changes as needed</a>. Any problems? Try asking ChatGPT to clarify how to merge - or contact me!<br/><br/>
#             After you've pulled the code, from the llm_engineering directory, in a Cursor Terminal, run:<br/>
#             <code>uv sync</code><br/>
#             </span>
#         </td>
#     </tr>
# </table>

# %% [markdown]
# <table style="margin: 0; text-align: left;">
#     <tr>
#         <td style="width: 150px; height: 150px; vertical-align: middle;">
#             <img src="../assets/important.jpg" width="150" height="150" style="display: block;" />
#         </td>
#         <td>
#             <h1 style="color:#900;">Important Note</h1>
#             <span style="color:#900;">
#             In this lab, I use high end models GPT 5, Claude 4.5 Sonnet, Gemini 2.5 Pro, Grok 4, which are the slightly higher priced models. The costs are still low, but if you'd prefer to keep costs ultra low, please pick lower cost models like gpt-5-nano.
#             </span>
#         </td>
#     </tr>
# </table>

# %%
# imports

import os
from dotenv import load_dotenv
from openai import OpenAI
import subprocess
from IPython.display import Markdown, display

# %%
# Initialization

# As an alternative, if you'd like to use Ollama instead of OpenAI
# Check that Ollama is running for you locally (see week1/day2 exercise) then uncomment these next 2 lines

ollama = OpenAI(base_url='http://localhost:11434/v1', api_key='ollama')
minimax = "minimax-m3:cloud";
llama = "llama3.2:3b"
phi3 = "phi3"

# %%
models = ollama.models.list()

for model in models.data:
    print(model.id)
# Out:
# llama3.2:3b
# phi3:latest

# %% [markdown]
# ## PLEASE NOTE:
#
# We will be writing a solution to convert Python into efficient, optimized C++ code for your machine, which can be compiled to native machine code and executed.
#
# It is not necessary for you to execute the code yourself - that's not the point of the exercise!
#
# But if you would like to (because it's satisfying!) then I'm including the steps here. Very optional!
#
# As an alternative, I'll also show you a website where you can run the C++ code.

# %%
from system_info import retrieve_system_info

system_info = retrieve_system_info()
system_info
# Out:
# {'os': {'system': 'Windows',
#   'arch': 'AMD64',
#   'release': '11',
#   'version': '10.0.26200',
#   'kernel': '11',
#   'distro': None,
#   'wsl': False,
#   'rosetta2_translated': False,
#   'target_triple': ''},
#  'package_managers': ['winget'],
#  'cpu': {'brand': 'Intel(R) Core(TM) i5-9600 CPU @ 3.10GHz',
#   'cores_logical': 6,
#   'cores_physical': 6,
#   'simd': []},
#  'toolchain': {'compilers': {'gcc': '', 'g++': '', 'clang': '', 'msvc_cl': ''},
#   'build_tools': {'cmake': '', 'ninja': '', 'make': ''},
#   'linkers': {'ld_lld': ''}}}

# %%
message = f"""
Here is a report of the system information for my computer.
I want to run a C++ compiler to compile a single C++ file called main.cpp and then execute it in the simplest way possible.
Please reply with whether I need to install any C++ compiler to do this. If so, please provide the simplest step by step instructions to do so.

If I'm already set up to compile C++ code, then I'd like to run something like this in Python to compile and execute the code:
```python
compile_command = # something here - to achieve the fastest possible runtime performance
compile_result = subprocess.run(compile_command, check=True, text=True, capture_output=True)
run_command = # something here
run_result = subprocess.run(run_command, check=True, text=True, capture_output=True)
return run_result.stdout
```
Please tell me exactly what I should use for the compile_command and run_command.

System information:
{system_info}
"""

response = ollama.chat.completions.create(model=phi3, messages=[{"role": "user", "content": message}])
display(Markdown(response.choices[0].message.content))
# Out:
# Based on the provided system information, it seems like you have Windows with an AMD64 architecture and Winget available as a package manager. Let's go through each part of your request:
#
# 1. To install MinGW-w64 to compile C++ files efficiently in Python using `subprocess`:
#    - Make sure the file paths are set correctly for commands executed via subprocess on Windows, and use double backslashes (`\\`) as path separators if needed. Alternatively, escape characters or raw strings can be used like so: `"C:\\Program Files"`. Replace `"main.cpp"` with your concrete input filename accordingly (e.g., `source_file = "c:/path/to/main.cpp"`).
#
# Install MinGW-w64 and set paths, here is the code to compile a simple C++ program using GCC:
#
# ```python
# import subprocess
# import os
#
# # Replace this with your actual source file relative or abspath as needed
# source_file = "c:/path/to/main.cpp" # Or just for Windows use only one forward slash '/' in path names, e.g., 'test.cpp'. On macOS and Linux you need to double backslashes ('\\') instead of a single slash('/'). Use raw string literals (r'C:\path\to\' or r'\home\username\sourcefile', respectively).
# exe_output = "c:/compiled/main.exe"  # Specify the output executable path here, but if not in source file directory this is also relative to 'source_file'. On Unix systems one needs double backslashes for paths like r'\somepath' (e.g., '/home/username\\folder').
# compile_command = f'g++ -o "{exe_output}" {source_file}'  # This command should compile the source file into an executable in Windows as well on Linux and macOS but with just one forward slash ('/' instead of '\\') for paths. Use raw string literals (r"gcc\ ... ") where g++ is followed by options here, you might not need any other switches besides "-Wall", which enables all the most useful warnings to be issued regarding potential problems in code quality: e.g., "compile_command = r'g++ -o "{exe_output}" {source_file}'".
# run_command = f"{exe_output} 'Hello, world!"  # Replace this with an appropriate command that you would normally use to execute your C++ program; for example: if a main.exe is produced it can simply be executed by the system call itself (no explicit invocation of "./file"). If there's no such mechanism on Windows then additional tools like 'start', e.g., with arguments, might get invoked in command prompt that starts your executable without needing to specify its full path because C++ executables usually don't store their paths internally so will be executed as .exe extension unless explicitly stated: f"{os.path.dirname(source_file)}\\helloWorld.exe 'Hello, MT!'".
# ```
# 2. Let me correct the provided Python script and run commands in your request for it to compile main.cpp using MinGW GCC Compiler after which I intend on executing the output file (assuming that there's a valid executable generated from compilation) as follows:
#    ```python
# import subprocess
# # Note : Replace all source_file and exe_output path names with actual paths to your project files. Be mindful of backslashes in folder/executable name or use double slashes ('\\' on windows, which should be escaped by '\\') for Windows commands here
# source_file = "c:/path/to/main.cpp" # Or just source file without absolute paths and let your operating system resolve it as needed. However remember to prefix an empty string with os module if you need full path names: f'{os.getenv("HOME") or "."}/{directory}/sourcefile'.
# exe_output = "c:/compiled/main"  # Again, be specific on where the output executable gets stored as your project files and compiler binary is fetched here using winget install MinGW-w64 GCC Compiler. Specify fully resolved path names if needed through os module otherwise with just source file name prefixing by a slash can work but remember that some operating systems like Linux might need double backslashes('\\') for paths (one forward '/').
# compile_command = r"g++ -std=c++14 -Wall '{source}' -o {output}"  # Compile source code using GCC compiler and output it as a C++ Executable. The command above is universal but with full relative/absolute path names where needed in your execution environment; remember to set '-std=' version flag depending on compatibility needs, e.g., 'c++14', here I chose the latest standard for now: g++ (MinGW-w64). And do not forget -o switch that defines output executable file you wish compiled source code will generate at during the compile time; we are expecting it to be main in this case, but if your program name differs simply replace 'main' with '.exe', or its path within our compilation command.
# run_command = f"{getenv('C:\\')}\\system32\\.\\{exe_output}.exe hello world!" # Execute the compiled executable as part of subprocess call; be advised that system32 directory itself might not contain executables (that's why using full or relative paths without '..' is recommended for better cross-os compatibility).
# result = subprocess.run(compile_command, check=True, text=True, capture_output=True) # Return result of compiling source code into executable file and also return stdout in Python variable; this might be empty as compilation does not produce output but run command can optionally retrieve the program's standard output: just execute without 'capture'.
# run_result = subprocess.run(run_command, check=True, text=True, capture_output=True) # Execute compiled executable which internally should print its content to stdout (e.g., in this example Hello world message), and return the result as Python variable where also captured output can be retrieved: just execute without 'capture'
# return run_result.stdout if you intend on using it immediately or saving for later use with e.g.: file = open("compiledAndRunResultsLogfile", "w") # Save compile and execution results to a log file as string in text format into your desired location that will be readable afterwards: just execute without 'capture'
# ``` Note that my return of the `run_result` is for demonstrative purposes; you can comment it out if not using stdout directly. Now, ensure MinGW-w64 (mingw32) has been installed via winget beforehand with something like: `'winget install --source=exactMinimum -e mingw-w64'`, replacing the executable names accordingly should match those generated by GCC during compilation. This instruction set will not only compile your C++ source but execute it immediately if possible (requires a compatible command line shell; 'cmd', Windows PowerShell, or an alternative such as PyCharm terminal etc.) and save output in variable `run_result` to be easily accessed later within Python scripts for instance.
#
# 3. Remember that invoking C++ executables directly from subprocess commands via system calls might vary per platform (e.g., Windows vs shell command syntax on Linux); my script assumes using MinGW installed via winget with its standard compilation and execution workflows, however feel free to explore Python-specific solutions involving scripts or direct file IO for different outcomes as needed beyond the scope of invoking C++ compiled executables this way without further details.

# %% [markdown]
# ## If you need to install something
#
# If you would like to, please follow GPTs instructions! Then rerun the analysis afterwards (you might need to Restart the notebook) to confirm you're set.
#
# You should now be equipped with the command to compile the code, and the command to run it!
#
# Enter that in the cell below:

# %%
compile_command = ["clang++", "-std=c++17", "-Ofast", "-mcpu=native", "-flto=thin", "-fvisibility=hidden", "-DNDEBUG", "main.cpp", "-o", "main"]
run_command = ["./main"]

# %% [markdown]
# ## And now, on with the main task

# %%
system_prompt = """
Your task is to convert Python code into high performance C++ code.
Respond only with C++ code. Do not provide any explanation other than occasional comments.
The C++ response needs to produce an identical output in the fastest possible time.
"""

def user_prompt_for(python):
    return f"""
Port this Python code to C++ with the fastest possible implementation that produces identical output in the least time.
The system information is:
{system_info}
Your response will be written to a file called main.cpp and then compiled and executed; the compilation command is:
{compile_command}
Respond only with C++ code.
Python code to port:

```python
{python}
```
"""

# %%
def messages_for(python):
    return [
        {"role": "system", "content": system_prompt},
        {"role": "user", "content": user_prompt_for(python)}
    ]

# %%
def write_output(cpp):
    with open("main.cpp", "w", encoding="utf-8") as f:
        f.write(cpp)

# %%
def port(client, model, python):
    reasoning_effort = "high" if 'gpt' in model else None
    response = client.chat.completions.create(model=model, messages=messages_for(python), reasoning_effort=reasoning_effort)
    reply = response.choices[0].message.content
    reply = reply.replace('```cpp','').replace('```','')
    write_output(reply)

# %%
pi = """
import time

def calculate(iterations, param1, param2):
    result = 1.0
    for i in range(1, iterations+1):
        j = i * param1 - param2
        result -= (1/j)
        j = i * param1 + param2
        result += (1/j)
    return result

start_time = time.time()
result = calculate(200_000_000, 4, 1) * 4
end_time = time.time()

print(f"Result: {result:.12f}")
print(f"Execution Time: {(end_time - start_time):.6f} seconds")
"""

# %%
def run_python(code):
    globals = {"__builtins__": __builtins__}
    exec(code, globals)

# %%
run_python(pi)
# Out:
# Result: 3.141592656089
# Execution Time: 33.780992 seconds

# %%
port(ollama, phi3, pi)

# %% [markdown]
# # Compiling C++ and executing
#
# This next cell contains the command to compile a C++ file based on the instructions from GPT.
#
# Again, it's not crucial to do this step if you don't wish to!
#
# OR alternatively: student Sandeep K.G. points out that you can run Python and C++ code online to test it out that way. Thank you Sandeep!
# > Not an exact comparison but you can still get the idea of performance difference.
# > For example here: https://www.programiz.com/cpp-programming/online-compiler/

# %%
# Use the commands from GPT 5

def compile_and_run():
    subprocess.run(compile_command, check=True, text=True, capture_output=True)
    print(subprocess.run(run_command, check=True, text=True, capture_output=True).stdout)
    print(subprocess.run(run_command, check=True, text=True, capture_output=True).stdout)
    print(subprocess.run(run_command, check=True, text=True, capture_output=True).stdout)

# %%
compile_and_run()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[16], line 1
# ----> 1 compile_and_run()
#
# Cell In[15], line 4, in compile_and_run()
#       3 def compile_and_run():
# ----> 4     subprocess.run(compile_command, check=True, text=True, capture_output=True)
#       5     print(subprocess.run(run_command, check=True, text=True, capture_output=True).stdout)
#       6     print(subprocess.run(run_command, check=True, text=True, capture_output=True).stdout)
#
# File ~\AppData\Roaming\uv\python\cpython-3.12.12-windows-x86_64-none\Lib\subprocess.py:548, in run(input, capture_output, timeout, check, *popenargs, **kwargs)
#     545     kwargs['stdout'] = PIPE
#     546     kwargs['stderr'] = PIPE
# --> 548 with Popen(*popenargs, **kwargs) as process:
#     549     try:
#     550         stdout, stderr = process.communicate(input, timeout=timeout)
#
# File ~\AppData\Roaming\uv\python\cpython-3.12.12-windows-x86_64-none\Lib\subprocess.py:1026, in Popen.__init__(self, args, bufsize, executable, stdin, stdout, stderr, preexec_fn, close_fds, shell, cwd, env, universal_newlines, startupinfo, creationflags, restore_signals, start_new_session, pass_fds, user, group, extra_groups, encoding, errors, text, umask, pipesize, process_group)
#    1022         if self.text_mode:
#    1023             self.stderr = io.TextIOWrapper(self.stderr,
#    1024                     encoding=encoding, errors=errors)
# -> 1026     self._execute_child(args, executable, preexec_fn, close_fds,
#    1027                         pass_fds, cwd, env,
#    1028                         startupinfo, creationflags, shell,
#    1029                         p2cread, p2cwrite,
#    1030                         c2pread, c2pwrite,
#    1031                         errread, errwrite,
#    1032                         restore_signals,
#    1033                         gid, gids, uid, umask,
#    1034                         start_new_session, process_group)
#    1035 except:
#    1036     # Cleanup if the child failed starting.
#    1037     for f in filter(None, (self.stdin, self.stdout, self.stderr)):
#
# File ~\AppData\Roaming\uv\python\cpython-3.12.12-windows-x86_64-none\Lib\subprocess.py:1538, in Popen._execute_child(self, args, executable, preexec_fn, close_fds, pass_fds, cwd, env, startupinfo, creationflags, shell, p2cread, p2cwrite, c2pread, c2pwrite, errread, errwrite, unused_restore_signals, unused_gid, unused_gids, unused_uid, unused_umask, unused_start_new_session, unused_process_group)
#    1536 # Start the process
#    1537 try:
# -> 1538     hp, ht, pid, tid = _winapi.CreateProcess(executable, args,
#    1539                              # no special security
#    1540                              None, None,
#    1541                              int(not close_fds),
#    1542                              creationflags,
#    1543                              env,
#    1544                              cwd,
#    1545                              startupinfo)
#    1546 finally:
#    1547     # Child is launched. Close the parent's copy of those pipe
#    1548     # handles that only the child should have open.  You need
#    (...)   1551     # pipe will not close when the child process exits and the
#    1552     # ReadFile will hang.
#    1553     self._close_pipe_fds(p2cread, p2cwrite,
#    1554                          c2pread, c2pwrite,
#    1555                          errread, errwrite)
#
# FileNotFoundError: [WinError 2] The system cannot find the file specified

# %%
19.178207/0.082168
# Out:
# 233.40238292279233

# %%
print(f"""
In Ed's experiments, the performance speedups were:

4th place: Claude Sonnet 4.5: {19.178207/0.104241:.0f}X speedup
3rd place: GPT-5: {19.178207/0.082168:.0f}X speedup
2nd place: Grok 4: {19.178207/0.018092:.0f}X speedup
1st place: Gemini 2.5 Pro: {19.178207/0.013314:.0f}X speedup
""")
# Out:
# In Ed's experiments, the performance speedups were:
#
# 4th place: Claude Sonnet 4.5: 184X speedup
# 3rd place: GPT-5: 233X speedup
# 2nd place: Grok 4: 1060X speedup
# 1st place: Gemini 2.5 Pro: 1440X speedup
